# %% [markdown]
# # 03 — Quantile Alignment
#
# Quantile alignment is treated as a fitted transformation and must be calibrated separately from evaluation data to prevent leakage.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("03 — Quantile Alignment" + " scaffold validated.")
