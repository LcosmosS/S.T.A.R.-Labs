# %% [markdown]
# # Mapping Benchmark
# \nControlled S.T.A.R. workflow notebook. Registry identifiers are placeholders until the experiment is formally locked.

# %%
from pathlib import Path
assert (Path.cwd()/"registry/claim_experiment_crosswalk_v0.2.csv").exists()
print("Mapping benchmark scaffold validated.")
