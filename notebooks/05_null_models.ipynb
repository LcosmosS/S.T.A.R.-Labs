# %% [markdown]
# # 05 — Null Models
#
# Null models are defined before evaluating observed structure and must carry a registered Null_ID.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("05 — Null Models" + " scaffold validated.")
