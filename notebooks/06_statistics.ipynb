# %% [markdown]
# # 06 — Statistics
#
# Statistical tests use the registered parameter and null-model definitions; exploratory results are not evidence until registered.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("06 — Statistics" + " scaffold validated.")
