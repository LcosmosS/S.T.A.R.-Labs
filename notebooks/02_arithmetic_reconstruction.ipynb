# %% [markdown]
# # Arithmetic Reconstruction
# \nControlled S.T.A.R. workflow notebook. Registry identifiers are placeholders until the experiment is formally locked.

# %%
from pathlib import Path
registry = Path.cwd()/"registry"
assert (registry/"experiment_registry_v0.2.csv").exists()
print("Arithmetic reconstruction scaffold validated.")
