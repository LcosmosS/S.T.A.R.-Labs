# %% [markdown]
# # 02 — Projection Benchmark
#
# Controlled comparison of registered arithmetic-to-cosmic mappings. Parameters and mapping definitions must be sourced from the experiment registry.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("02 — Projection Benchmark" + " scaffold validated.")
