# %% [markdown]
# # 07 — Robustness
#
# Robustness analyses vary only registered parameter sets and preserve the primary experiment definition.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("07 — Robustness" + " scaffold validated.")
