# %% [markdown]
# # 01 — Data Validation
#
# This controlled notebook validates registry/data prerequisites without silently dropping the entire sample. Historical preprocessing logic is retained under `historical/legacy_notebooks/`.

# %%
from pathlib import Path
import csv

root = Path.cwd()
registry = root / "registry"
required = ["claim_evidence_v0.2.csv", "experiment_registry_v0.2.csv"]
for name in required:
    assert (registry / name).exists(), f"missing registry file: {name}"
print("Registry prerequisites present.")
