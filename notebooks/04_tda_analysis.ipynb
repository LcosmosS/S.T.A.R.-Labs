# %% [markdown]
# # 04 — TDA Analysis
#
# Persistent-homology analysis requires registered topology parameters and explicit GUDHI availability; no silent fallback is permitted.

# %%
from pathlib import Path
registry = Path.cwd() / "registry"
assert registry.exists(), "registry directory is required"
print("04 — TDA Analysis" + " scaffold validated.")
